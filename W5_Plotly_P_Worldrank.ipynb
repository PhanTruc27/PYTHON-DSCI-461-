# %% [markdown]
# <div class="alert alert-block alert-info">
# <b> Keywords: plots in plotly.express </b>
#     <br>
#     * data -> TOP universities all over the world from 2011-2016
#     <br>
#     * AIM-> show how to create the most common plots using plotly.express library </div>
#
# - Line Charts
# - Scatter plot
# - Bar Charts
# - Bubble Charts
# - Histogram
# - Word Cloud
# - Box Plots
# -  Scatter Matrix Plots
# - 3D Scatter Plot with Colorscaling

# %% [markdown]
# # Plotly library
#
# ![image.png](attachment:image.png)
#
#  Plotly's Python graphing library makes interactive, publication-quality graphs online. Examples of how to make line plots, scatter plots, area charts, bar charts, error bars, box plots, histograms, heatmaps, subplots, multiple-axes, polar charts, and bubble charts.

# %%
import sys
sys.version
# Out:
# '3.12.7 | packaged by Anaconda, Inc. | (main, Oct  4 2024, 13:17:27) [MSC v.1929 64 bit (AMD64)]'

# %%
# 1. Install the following library
#!pip install plotly==6.1.1
import numpy as pd

# %%
# !pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.6-cp312-cp312-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\hp\anaconda3\lib\site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in c:\users\hp\anaconda3\lib\site-packages (from wordcloud) (10.4.0)
# Requirement already satisfied: matplotlib in c:\users\hp\anaconda3\lib\site-packages (from wordcloud) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->wordcloud) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\hp\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Downloading wordcloud-1.9.6-cp312-cp312-win_amd64.whl (307 kB)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.6

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objs as go
# word cloud library
from wordcloud import WordCloud



import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading Data and Explanation of Features

# %% [markdown]
# <font color='blue'>
#
#
#
# * timesData includes 14 features that are:
#
#     <font color='black'>
#
#     * world_rank
#     * university_name
#     * country
#     * teaching
#     * international
#     * research
#     * citations
#     * income
#     * total_score
#     * num_students
#     * student_staff_ratio
#     * international_students
#     * female_male_ratio
#     * year

# %%
# Load data of 5timesData
timeDate = pd.read_csv('5TimesData.csv')
timeDate
# Out:
#      world_rank                        university_name  \
# 0             1                     Harvard University
# 1             2     California Institute of Technology
# 2             3  Massachusetts Institute of Technology
# 3             4                    Stanford University
# 4             5                   Princeton University
# ...         ...                                    ...
# 2598    601-800                    Yeungnam University
# 2599    601-800            Yıldız Technical University
# 2600    601-800               Yokohama City University
# 2601    601-800           Yokohama National University
# 2602    601-800                     Yuan Ze University
#
#                        country  teaching international  research  citations  \
# 0     United States of America      99.7          72.4      98.7       98.8
# 1     United States of America      97.7          54.6      98.0       99.9
# 2     United States of America      97.8          82.3      91.4       99.9
# 3     United States of America      98.3          29.5      98.1       99.2
# 4     United States of America      90.9          70.3      95.4       99.9
# ...                        ...       ...           ...       ...        ...
# 2598               South Korea      18.6          24.3      10.9       26.5
# 2599                    Turkey      14.5          14.9       7.6       19.3
# 2600                     Japan      24.0          16.1      10.2       36.4
# 2601                     Japan      20.1          23.3      16.0       13.5
# 2602                    Taiwan      16.2          17.7      18.3       28.6
#
#      income total_score num_students  student_staff_ratio  \
# 0      34.5        96.1       20,152                  8.9
# 1      83.7        96.0        2,243                  6.9
# 2      87.5        95.6       11,074                  9.0
# 3      64.3        94.3       15,596                  7.8
# 4         -        94.2        7,929                  8.4
# ...     ...         ...          ...                  ...
# 2598   35.4           -       21,958                 15.3
# 2599   44.0           -       31,268                 28.7
# 2600   37.9           -        4,122                  3.7
# 2601   40.4           -       10,117                 12.1
# 2602   39.8           -        8,663                 20.6
#
#      international_students female_male_ratio  year
# 0                       25%               NaN  2011
# 1                       27%           33 : 67  2011
# 2                       33%           37 : 63  2011
# 3                       22%           42 : 58  2011
# 4                       27%           45 : 55  2011
# ...                     ...               ...   ...
# 2598                     3%           48 : 52  2016
# 2599                     2%           36 : 64  2016
# 2600                     3%               NaN  2016
# 2601                     8%           28 : 72  2016
# 2602                     4%           43 : 57  2016
#
# [2603 rows x 14 columns]

# %%
timeDate.isnull().sum()
# Out:
# world_rank                  0
# university_name             0
# country                     0
# teaching                    0
# international               0
# research                    0
# citations                   0
# income                      0
# total_score                 0
# num_students               59
# student_staff_ratio        59
# international_students     67
# female_male_ratio         233
# year                        0
# dtype: int64

# %%
timeDate.dropna(inplace = True)

# %%
timeDate.isnull().sum()
# Out:
# world_rank                0
# university_name           0
# country                   0
# teaching                  0
# international             0
# research                  0
# citations                 0
# income                    0
# total_score               0
# num_students              0
# student_staff_ratio       0
# international_students    0
# female_male_ratio         0
# year                      0
# dtype: int64

# %%
timeDate.duplicated().sum()
# Out:
# 0

# %%
timeDate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2362 entries, 1 to 2602
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   world_rank              2362 non-null   object
#  1   university_name         2362 non-null   object
#  2   country                 2362 non-null   object
#  3   teaching                2362 non-null   float64
#  4   international           2362 non-null   object
#  5   research                2362 non-null   float64
#  6   citations               2362 non-null   float64
#  7   income                  2362 non-null   object
#  8   total_score             2362 non-null   object
#  9   num_students            2362 non-null   object
#  10  student_staff_ratio     2362 non-null   float64
#  11  international_students  2362 non-null   object
#  12  female_male_ratio       2362 non-null   object
#  13  year                    2362 non-null   int64
# dtypes: float64(4), int64(1), object(9)
# memory usage: 276.8+ KB

# %% [markdown]
# # Line Charts
#
# Line Charts Example: Citation and Teaching vs World Rank of Top 100 Universities

# %% [markdown]
# `Plotly Express`: a terse, consistent, high-level API for creating figures.
#
# https://plotly.com/python/plotly-express/

# %%
import pandas as pd
df = pd.read_csv('5TimesData.csv')
df.head()
# Out:
#   world_rank                        university_name                   country  \
# 0          1                     Harvard University  United States of America
# 1          2     California Institute of Technology  United States of America
# 2          3  Massachusetts Institute of Technology  United States of America
# 3          4                    Stanford University  United States of America
# 4          5                   Princeton University  United States of America
#
#    teaching international  research  citations income total_score  \
# 0      99.7          72.4      98.7       98.8   34.5        96.1
# 1      97.7          54.6      98.0       99.9   83.7        96.0
# 2      97.8          82.3      91.4       99.9   87.5        95.6
# 3      98.3          29.5      98.1       99.2   64.3        94.3
# 4      90.9          70.3      95.4       99.9      -        94.2
#
#   num_students  student_staff_ratio international_students female_male_ratio  \
# 0       20,152                  8.9                    25%               NaN
# 1        2,243                  6.9                    27%           33 : 67
# 2       11,074                  9.0                    33%           37 : 63
# 3       15,596                  7.8                    22%           42 : 58
# 4        7,929                  8.4                    27%           45 : 55
#
#    year
# 0  2011
# 1  2011
# 2  2011
# 3  2011
# 4  2011

# %%
import plotly.io as pio
#pio.renderers.default = "browser"
pio.renderers.default = "jupyterlab"

# %%
# Top 100 University , cai nay la object
#top_100 = df[df['world_rank'] <= 100]

# %%
df['world_rank_clean'] = df['world_rank'].astype(str).str.strip().str.lstrip('=')
df['world_rank_clean']
# Out:
# 0             1
# 1             2
# 2             3
# 3             4
# 4             5
#          ...
# 2598    601-800
# 2599    601-800
# 2600    601-800
# 2601    601-800
# 2602    601-800
# Name: world_rank_clean, Length: 2603, dtype: object

# %%
df['world_rank_int'] = pd.to_numeric(df['world_rank_clean'], errors='coerce').astype('Int64')
df['world_rank_int']
# Out:
# 0          1
# 1          2
# 2          3
# 3          4
# 4          5
#         ...
# 2598    <NA>
# 2599    <NA>
# 2600    <NA>
# 2601    <NA>
# 2602    <NA>
# Name: world_rank_int, Length: 2603, dtype: Int64

# %%
df_nan=df[df['world_rank_int'].isnull()==True]
df_nan['world_rank'].unique()
# Out:
# array(['201-225', '226-250', '251-275', '276-300', '301-350', '350-400',
#        '351-400', '201-250', '251-300', '401-500', '501-600', '601-800'],
#       dtype=object)

# %%
#The dataset can apply some cleaning steps on (at least) column world_rank, before visualization.
df1=df[:100]
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   world_rank              100 non-null    object
#  1   university_name         100 non-null    object
#  2   country                 100 non-null    object
#  3   teaching                100 non-null    float64
#  4   international           100 non-null    object
#  5   research                100 non-null    float64
#  6   citations               100 non-null    float64
#  7   income                  100 non-null    object
#  8   total_score             100 non-null    object
#  9   num_students            97 non-null     object
#  10  student_staff_ratio     97 non-null     float64
#  11  international_students  97 non-null     object
#  12  female_male_ratio       85 non-null     object
#  13  year                    100 non-null    int64
#  14  word_rank_clean         100 non-null    object
#  15  world_rank_clean        100 non-null    object
#  16  world_rank_int          100 non-null    Int64
# dtypes: Int64(1), float64(4), int64(1), object(11)
# memory usage: 13.5+ KB

# %%
# Create the traces of the plots
px.line(df1 , x='world_rank_int',y = ['citations','teaching'],
       hover_name = 'university_name')

# %% [markdown]
# # Scatter plot
#
#
#     Scatter Example: Citation vs world rank of top 100 universities with 2014, 2015 and 2016 years

# %%
# Extract the required data
df.year.unique()
# Out:
# array([2011, 2012, 2013, 2014, 2015, 2016], dtype=int64)

# %%
df_years = df[df.year >= 2014]
df_years.year.unique()
# Out:
# array([2014, 2015, 2016], dtype=int64)

# %%
df_years = df_years[:100]
df_years
# Out:
#      world_rank                        university_name  \
# 1002          1     California Institute of Technology
# 1003          2                     Harvard University
# 1004          2                   University of Oxford
# 1005          4                    Stanford University
# 1006          5  Massachusetts Institute of Technology
# ...         ...                                    ...
# 1097         96      Pierre and Marie Curie University
# 1098         97         University of Colorado Boulder
# 1099         98                  Maastricht University
# 1100         98                University of Groningen
# 1101        100                 University of Helsinki
#
#                        country  teaching international  research  citations  \
# 1002  United States of America      94.4          65.8      98.2       99.8
# 1003  United States of America      95.3          66.2      98.5       99.1
# 1004            United Kingdom      89.0          90.2      98.5       95.4
# 1005  United States of America      94.7          68.0      96.8       99.1
# 1006  United States of America      92.9          82.0      89.0      100.0
# ...                        ...       ...           ...       ...        ...
# 1097                    France      50.2          65.5      26.7       82.3
# 1098  United States of America      34.2          40.5      33.3       97.3
# 1099               Netherlands      33.1          89.1      47.1       65.8
# 1100               Netherlands      36.0          53.0      48.6       71.1
# 1101                   Finland      35.5          51.3      46.5       77.8
#
#      income total_score num_students  student_staff_ratio  \
# 1002   91.2        94.9        2,243                  6.9
# 1003   40.6        93.9       20,152                  8.9
# 1004   90.3        93.9       19,919                 11.6
# 1005   61.3        93.8       15,596                  7.8
# 1006   94.3        93.0       11,074                  9.0
# ...     ...         ...          ...                  ...
# 1097   34.4        53.5       27,862                  8.7
# 1098      -        53.4       29,325                 16.1
# 1099   98.2        52.9       15,626                 18.9
# 1100   87.6        52.9       24,556                 25.6
# 1101   30.7        52.6       23,505                 15.1
#
#      international_students female_male_ratio  year word_rank_clean  \
# 1002                    27%           33 : 67  2014               1
# 1003                    25%               NaN  2014               2
# 1004                    34%           46 : 54  2014               2
# 1005                    22%           42 : 58  2014               4
# 1006                    33%           37 : 63  2014               5
# ...                     ...               ...   ...             ...
# 1097                    18%           48 : 52  2014              96
# 1098                     8%           45 : 55  2014              97
# 1099                    48%           56 : 44  2014              98
# 1100                    12%           52 : 48  2014              98
# 1101                     6%           66 : 34  2014             100
#
#      world_rank_clean  world_rank_int
# 1002                1               1
# 1003                2               2
# 1004                2               2
# 1005                4               4
# 1006                5               5
# ...               ...             ...
# 1097               96              96
# 1098               97              97
# 1099               98              98
# 1100               98              98
# 1101              100             100
#
# [100 rows x 17 columns]

# %%
# Step 1: Create the traces of the plots
px.scatter(df_years,
           x='world_rank_int',
           y='citations',
           color='country').show()

# %%
 # Step 2: Update the layout of the plot
px.scatter(df_years,
           x='world_rank_int',
           y='citations',
           color='country').show()
fig.update_layout(
    title_text='Citation vs World Rank of Top 100 Universities (2014–2016)'
)

fig.update_xaxes(title='World Rank')
fig.update_yaxes(title='Citation')

# Rank nhỏ là tốt hơn → đảo trục X (ăn điểm)
fig.update_xaxes(autorange='reversed')

fig.show()

# %% [markdown]
# # Bar Charts
#
#
#     First Bar Charts Example: citations and teaching of top 5 universities in 2014 (style1)

# %%
df2014.columns
# Out:
# Index(['world_rank', 'university_name', 'country', 'teaching', 'international',
#        'research', 'citations', 'income', 'total_score', 'num_students',
#        'student_staff_ratio', 'international_students', 'female_male_ratio',
#        'year', 'word_rank_clean', 'world_rank_clean', 'world_rank_int'],
#       dtype='object')

# %%
df.sort_values('world_rank_int')
# Out:
#      world_rank                     university_name                   country  \
# 0             1                  Harvard University  United States of America
# 1803          1  California Institute of Technology  United States of America
# 1402          1  California Institute of Technology  United States of America
# 602           1  California Institute of Technology  United States of America
# 200           1  California Institute of Technology  United States of America
# ...         ...                                 ...                       ...
# 2598    601-800                 Yeungnam University               South Korea
# 2599    601-800         Yıldız Technical University                    Turkey
# 2600    601-800            Yokohama City University                     Japan
# 2601    601-800        Yokohama National University                     Japan
# 2602    601-800                  Yuan Ze University                    Taiwan
#
#       teaching international  research  citations income total_score  \
# 0         99.7          72.4      98.7       98.8   34.5        96.1
# 1803      95.6          64.0      97.6       99.8   97.8        95.2
# 1402      92.2          67.0      98.1       99.7   89.1        94.3
# 602       96.3          59.8      99.4       99.7   95.6        95.5
# 200       95.7          56.0      98.2       99.9   97.0        94.8
# ...        ...           ...       ...        ...    ...         ...
# 2598      18.6          24.3      10.9       26.5   35.4           -
# 2599      14.5          14.9       7.6       19.3   44.0           -
# 2600      24.0          16.1      10.2       36.4   37.9           -
# 2601      20.1          23.3      16.0       13.5   40.4           -
# 2602      16.2          17.7      18.3       28.6   39.8           -
#
#      num_students  student_staff_ratio international_students  \
# 0          20,152                  8.9                    25%
# 1803        2,243                  6.9                    27%
# 1402        2,243                  6.9                    27%
# 602         2,243                  6.9                    27%
# 200         2,243                  6.9                    27%
# ...           ...                  ...                    ...
# 2598       21,958                 15.3                     3%
# 2599       31,268                 28.7                     2%
# 2600        4,122                  3.7                     3%
# 2601       10,117                 12.1                     8%
# 2602        8,663                 20.6                     4%
#
#      female_male_ratio  year word_rank_clean world_rank_clean  world_rank_int
# 0                  NaN  2011               1                1               1
# 1803           33 : 67  2016               1                1               1
# 1402           33 : 67  2015               1                1               1
# 602            33 : 67  2013               1                1               1
# 200            33 : 67  2012               1                1               1
# ...                ...   ...             ...              ...             ...
# 2598           48 : 52  2016         601-800          601-800            <NA>
# 2599           36 : 64  2016         601-800          601-800            <NA>
# 2600               NaN  2016         601-800          601-800            <NA>
# 2601           28 : 72  2016         601-800          601-800            <NA>
# 2602           43 : 57  2016         601-800          601-800            <NA>
#
# [2603 rows x 17 columns]

# %%
# Extract required data
df2014 = df[ df.year == 2014 ][:5]

# %%
# Define a color list for each university
colors_2014 = ['DarkCyan', 'Chartreuse', 'OrangeRed']

# %%
# Create the bar chart
fig = px.bar(
    df2014,
    x='university_name',
    y=['citations', 'teaching', 'research'],
    color_discrete_sequence=colors_2014
)

# Update the layout of the plot
fig.update_layout(barmode='group')

# Show the plot
fig.show()

# %% [markdown]
#     Stacked Bar

# %%
# Step 1: Create the traces of the plots


 # Step 2: Update the layout of the plot

# %% [markdown]
#     Second Bar Charts Example: citations and teaching of top 5 universities in 2014 (style2)

# %%
# prepare data frames

# %%
# Create the traces of the plots

# %% [markdown]
# # Bubble Charts
#
#     Bubble Charts Example: University world rank (first 20) vs teaching score with income (size) and international score (color) in 2014
#
#
#
# * x = x axis
# * y = y axis
# * mode = markers(scatter)
# *  marker = marker properties
#     * color = third dimension of plot. Internaltional score
#     * size = fourth dimension of plot. Number of students
# * text: university names

# %%
# data preparation

# %%
# Step 1: Create the traces of the plots
#Step 2: update layout

# %% [markdown]
# # Histogram
#     Lets look at histogram of students-staff ratio in 2014 and 2016 years.

# %%
#Extract data

# %%
# Step 1: Create the traces of the plots


# Step 2: Update the layout of the plot

# %% [markdown]
# # Word Cloud
#
# Not a pyplot but learning it is good for visualization. Lets look at which country is mentioned most in 2011.
# * WordCloud = word cloud library that I import at the beginning of kernel
#     * background_color = color of back ground
#     * generate = generates the country name list(x2011) a word cloud

# %%
# data preparation

# %%
wordcloud = WordCloud(background_color='blue',
                      width=300,
                      height=400)
wordcloud.generate(' '.join(x2011))
plt.imshow(wordcloud)
plt.axis('off')
# Out:
# (-0.5, 299.5, 399.5, -0.5)

# %%
wordcloud = WordCloud(background_color='white',
                          width=512,
                          height=384)
wordcloud.generate(" ".join(x2011))

plt.imshow(wordcloud)
plt.axis('off')
plt.savefig('graph.png')

#plt.show()

# %% [markdown]
# # Box Plots
#
# * Box Plots
#     * Median (50th percentile) = middle value of the data set. Sort and take the data in the middle. It is also called 50% percentile that is 50% of data are less that median(50th quartile)(quartile)
#         * 25th percentile = quartile 1 (Q1) that is lower quartile
#         * 75th percentile = quartile 3 (Q3) that is higher quartile
#         * height of box = IQR = interquartile range = Q3-Q1
#         * Whiskers = 1.5 * IQR from the Q1 and Q3
#         * Outliers = being more than 1.5*IQR away from median commonly.
#
#     * trace = box
#         * y = data we want to visualize with box plot
#         * marker = color

# %%
# data preparation
df2014
# Out:
#      world_rank                                    university_name  \
# 1002          1                 California Institute of Technology
# 1003          2                                 Harvard University
# 1004          2                               University of Oxford
# 1005          4                                Stanford University
# 1006          5              Massachusetts Institute of Technology
# 1007          6                               Princeton University
# 1008          7                            University of Cambridge
# 1009          8                 University of California, Berkeley
# 1010          9                              University of Chicago
# 1011         10                            Imperial College London
# 1012         11                                    Yale University
# 1013         12              University of California, Los Angeles
# 1014         13                                Columbia University
# 1015         14  ETH Zurich – Swiss Federal Institute of Techno...
# 1016         15                           Johns Hopkins University
# 1017         16                         University of Pennsylvania
# 1018         17                                    Duke University
# 1019         18                             University of Michigan
# 1020         19                                 Cornell University
# 1021         20                              University of Toronto
#
#                        country  teaching  international  research  citations  \
# 1002  United States of America      94.4           65.8      98.2       99.8
# 1003  United States of America      95.3           66.2      98.5       99.1
# 1004            United Kingdom      89.0           90.2      98.5       95.4
# 1005  United States of America      94.7           68.0      96.8       99.1
# 1006  United States of America      92.9           82.0      89.0      100.0
# 1007  United States of America      89.9           59.6      97.6       99.7
# 1008            United Kingdom      90.6           86.7      95.3       95.7
# 1009  United States of America      83.2           57.3      97.5       99.3
# 1010  United States of America      85.6           58.6      88.2       98.0
# 1011            United Kingdom      84.5           91.8      88.1       90.0
# 1012  United States of America      89.5           57.6      90.5       93.5
# 1013  United States of America      84.8           46.4      91.0       95.6
# 1014  United States of America      86.6           68.0      79.1       95.6
# 1015               Switzerland      77.6           96.7      88.2       85.0
# 1016  United States of America      75.7           59.3      85.1       95.0
# 1017  United States of America      79.8           40.6      81.2       95.0
# 1018  United States of America      73.9           50.0      73.0       96.7
# 1019  United States of America      70.0           49.5      86.2       90.8
# 1020  United States of America      72.1           55.6      83.8       90.8
# 1021                    Canada      73.6           70.0      81.5       84.5
#
#       income total_score num_students  student_staff_ratio  \
# 1002    91.2        94.9        2,243                  6.9
# 1003    40.6        93.9       20,152                  8.9
# 1004    90.3        93.9       19,919                 11.6
# 1005    61.3        93.8       15,596                  7.8
# 1006    94.3        93.0       11,074                  9.0
# 1007    80.5        92.7        7,929                  8.4
# 1008    52.8        92.3       18,812                 11.8
# 1009    59.5        89.8       36,186                 16.4
# 1010     0.0        87.8       14,221                  6.9
# 1011    72.3        87.5       15,060                 11.7
# 1012    38.7        87.4       11,751                  4.4
# 1013     0.0        86.3       38,206                 10.3
# 1014     0.0        85.2       25,055                  5.9
# 1015    78.8        84.5       18,178                 14.7
# 1016   100.0        83.7       15,128                  3.6
# 1017    45.2        81.0       20,376                  6.5
# 1018   100.0        79.3       15,172                  4.8
# 1019    53.5        79.2       41,786                  9.0
# 1020    35.8        79.1       21,424                 10.2
# 1021    45.8        78.3       66,198                 19.5
#
#      international_students female_male_ratio  year
# 1002                    27%           33 : 67  2014
# 1003                    25%           54 : 46  2014
# 1004                    34%           46 : 54  2014
# 1005                    22%           42 : 58  2014
# 1006                    33%           37 : 63  2014
# 1007                    27%           45 : 55  2014
# 1008                    34%           46 : 54  2014
# 1009                    15%           50 : 50  2014
# 1010                    21%           42 : 58  2014
# 1011                    51%           37 : 63  2014
# 1012                    20%           50 : 50  2014
# 1013                    15%           52 : 48  2014
# 1014                    28%           54 : 46  2014
# 1015                    37%           31 : 69  2014
# 1016                    23%           50 : 50  2014
# 1017                    20%           51 : 49  2014
# 1018                    17%           49 : 51  2014
# 1019                    16%           48 : 52  2014
# 1020                    19%           48 : 52  2014
# 1021                    15%           54 : 46  2014

# %%
df2014['num_students'] = df2014['num_students'].str.replace(',','')
df2014['num_students'].unique()
# Out:
# array(['2243', '20152', '19919', '15596', '11074', '7929', '18812',
#        '36186', '14221', '15060', '11751', '38206', '25055', '18178',
#        '15128', '20376', '15172', '41786', '21424', '66198', '26607',
#        '18334', '26199', '11885', '44020', '31592', '49427', '19967',
#        '42727', '39655', '50152', '10221', '22020', '40128', '31326',
#        '7774', '9666', '21394', '25774', '42056', '27233', '12528',
#        '19835', '26389', '40148', '46825', '26518', '14604', '44501',
#        '24789', '39763', '8653', '22809', '35364', '35691', '9027',
#        '11385', '34938', '51462', '3055', '42503', '39256', '34718',
#        '25581', '6333', '2400', '21222', '28881', '15920', '36534',
#        '2429', '41868', '20580', '12551', '30779', '25028', '9248',
#        '26485', '17906', '15489', '12338', '10410', '44750', '24570',
#        '32166', '33062', '35565', '9259', '12161', '11829', '50882',
#        '23823', '26614', '29987', '9390', '27862', '29325', '15626',
#        '24556', '23505', '8747', '37032', '31715', '36429', '8176',
#        '38264', '31331', '17916', '36299', '25266', '23311', '23845',
#        '27603', '14260', '38309', '12062', '9990', '22616', '8338',
#        '12001', '26583', '28251', '15668', '9586', '6178', '20040',
#        '50095', '37917', '15521', '17713', '62468', '11964', '56959',
#        '13216', '17404', '11512', '23895', '5287', '27703', '18529',
#        '31891', '25674', '23144', '23280', '83236', '20925', '20626',
#        '17755', '17200', '27545', '26467', '25295', '25294', '16130',
#        '2218', '14708', '30144', '50657', '15408', '22193', '27526',
#        '14541', '5495', '10901', '12346', '29787', '20851', '18815',
#        '6631', '34651', '28856', '6753', '19262', '14992', '25668',
#        '23819', '27756', '21908', '7326', '6671', '32474', '29991',
#        '18539', '15286', '27139', '36733', '12938', '16306', '24774',
#        '17612', '24313', '1283', '20541', '12050', '11628', '4408',
#        '20174', '11506', '23977', '9454', '23347', '10015', '32175',
#        '31861', '34550', '24043', '27227', '25779', '15529', '2958',
#        '24365', '13855', '9303', '9187', '20771', '11623', '28341',
#        '26420', '18209', '14290', '46208', '16841', '28327', '17581',
#        '7867', '30538', '30822', '16691', '20488', '24954', '26640',
#        '20300', '7576', '11381', '47491', '36108', '36146', '24444',
#        '10930', '33370', '39838', '18600', '81402', '23321', '18135',
#        '67552', '30726', '27387', '26576', '26419', '12613', '15064',
#        '22064', '7426', '36731', '29743', '12646', '17381', '17940',
#        '10977', '3879', '35487', '43280', '12695', '13960', '21789',
#        '23508', '22958', '29336', '15773', '9020', '25036', '8605',
#        '26769', '7086', '4488', '27930', '24121', '30025', '33391',
#        '2872', '15805', '3837', '12830', '85532', '10416', '33119',
#        '58618', '12470', '31424', '22210', '16489', '17142', '30850',
#        '48007', '17422', '16099', '9252', '28296', '9567', '12520',
#        '21428', '35308', '32713', '20713', '8773', '18162', '10441',
#        '21379', '8397', '17791', '18925', '6300', '17866', '16606',
#        '21234', '9336', '14067', '22578', '120986', '38191', '27095',
#        '15387', '21849', '16667', '12187', '25742', '14650', '10798',
#        '19665', '40325', '20951', '28576', '29885', '62577', '47247',
#        '19959', '18971', '10045', '24519', '15930', '10159', '49292',
#        '24550', '23065', '50260', '47508', '5570', '51438', '7983',
#        '26622', '16729', '8371', '6167', '9928', '8061', '19646', '35889',
#        '40666', '22401', '18513', '13951', '10915', '7446', '7653',
#        '33172', '38675', '27420', '51351', '20314', '33268', '10398',
#        '51560', '36051', '18882', '54290', '20584', '21643', '9703',
#        '13908', '19090', '11259', '32720', '20161', '12533', '7828',
#        '12063', '10269', '18340', '58413', '22793'], dtype=object)

# %%
df2014['num_students'] = df2014['num_students'].astype(int)

# %%
fig = px.box(df2014, x ='total_score')
fig.show()

# %%
fig = px.box(df2014, y ='num_students', points="suspectedoutliers")
fig.show()

# %%
fig = px.box(df2014, x ='country',y="total_score", color = 'country',
             points="suspectedoutliers")
fig.show()

# %% [markdown]
# # Scatter Matrix Plots
# Scatter Matrix = it helps us to see covariance and relation between more than 2 features
#
# * import figure factory as ff
# * create_scatterplotmatrix = creates scatter plot
#     * data2015 = prepared data. It includes research, international and total scores with index from 1 to 401
#     * colormap = color map of scatter plot
#     * colormap_type = color type of scatter plot
#     * height and weight

# %%
# import figure factory
import plotly.figure_factory as ff

# %%
data2014 = df2014.loc[:,["research","international", "total_score"]]
data2014
# Out:
#       research  international total_score
# 1002      98.2           65.8        94.9
# 1003      98.5           66.2        93.9
# 1004      98.5           90.2        93.9
# 1005      96.8           68.0        93.8
# 1006      89.0           82.0        93.0
# 1007      97.6           59.6        92.7
# 1008      95.3           86.7        92.3
# 1009      97.5           57.3        89.8
# 1010      88.2           58.6        87.8
# 1011      88.1           91.8        87.5
# 1012      90.5           57.6        87.4
# 1013      91.0           46.4        86.3
# 1014      79.1           68.0        85.2
# 1015      88.2           96.7        84.5
# 1016      85.1           59.3        83.7
# 1017      81.2           40.6        81.0
# 1018      73.0           50.0        79.3
# 1019      86.2           49.5        79.2
# 1020      83.8           55.6        79.1
# 1021      81.5           70.0        78.3

# %%
# scatter matrix
fig = ff.create_scatterplotmatrix(data2014, diag='box',colormap='Portland',
                                  height=700, width=700)
fig.show()

# %% [markdown]
# # 3D Scatter Plot with Colorscaling
#
#     3D Scatter: Sometimes 2D is not enough to understand data. Therefore adding one more dimension increase the intelligibility of the data. Even we will add color that is actually 4th dimension.
#
#
#
# * go.Scatter3d: create 3d scatter plot
# * x,y,z: axis of plots
# * mode: market that is scatter
# * size: marker size
# * color: axis of colorscale
# * colorscale:  actually it is 4th dimension

# %%
# Always prepare data frames
df2014 = timesData[timesData.year == 2014]
df2014
# Out:
#      world_rank                        university_name  \
# 1002          1     California Institute of Technology
# 1003          2                     Harvard University
# 1004          2                   University of Oxford
# 1005          4                    Stanford University
# 1006          5  Massachusetts Institute of Technology
# ...         ...                                    ...
# 1397    351-400                    University of Tartu
# 1398    351-400                 University of Tasmania
# 1399    351-400                 University of Valencia
# 1400    351-400                     University of Vigo
# 1401    351-400                  University of Wyoming
#
#                        country  teaching international  research  citations  \
# 1002  United States of America      94.4          65.8      98.2       99.8
# 1003  United States of America      95.3          66.2      98.5       99.1
# 1004            United Kingdom      89.0          90.2      98.5       95.4
# 1005  United States of America      94.7          68.0      96.8       99.1
# 1006  United States of America      92.9          82.0      89.0      100.0
# ...                        ...       ...           ...       ...        ...
# 1397                   Estonia      20.3          43.7      21.2       46.2
# 1398                 Australia      18.7          69.9      16.7       49.1
# 1399                     Spain      16.6          39.3      12.4       59.0
# 1400                     Spain      19.7          25.9      10.7       62.9
# 1401  United States of America      18.9          29.7      28.6       46.1
#
#      income total_score num_students  student_staff_ratio  \
# 1002   91.2        94.9        2,243             6.900000
# 1003   40.6        93.9       20,152             8.900000
# 1004   90.3        93.9       19,919            11.600000
# 1005   61.3        93.8       15,596             7.800000
# 1006   94.3        93.0       11,074             9.000000
# ...     ...         ...          ...                  ...
# 1397   30.3           -       10,269            13.000000
# 1398   36.9           -       18,340            23.800000
# 1399   31.7           -       58,413            15.400000
# 1400   38.2           -       22,793            19.000000
# 1401   29.6           -       10,221            18.445283
#
#      international_students female_male_ratio  year
# 1002                    27%           33 : 67  2014
# 1003                    25%           54 : 46  2014
# 1004                    34%           46 : 54  2014
# 1005                    22%           42 : 58  2014
# 1006                    33%           37 : 63  2014
# ...                     ...               ...   ...
# 1397                     3%           66 : 34  2014
# 1398                    21%           57 : 43  2014
# 1399                     9%           60 : 40  2014
# 1400                     3%           51 : 49  2014
# 1401                     7%           54 : 46  2014
#
# [400 rows x 14 columns]

# %%
timesData
# Out:
#      world_rank                        university_name  \
# 0             1                     Harvard University
# 1             2     California Institute of Technology
# 2             3  Massachusetts Institute of Technology
# 3             4                    Stanford University
# 4             5                   Princeton University
# ...         ...                                    ...
# 2598    601-800                    Yeungnam University
# 2599    601-800            Yıldız Technical University
# 2600    601-800               Yokohama City University
# 2601    601-800           Yokohama National University
# 2602    601-800                     Yuan Ze University
#
#                        country  teaching international  research  citations  \
# 0     United States of America      99.7          72.4      98.7       98.8
# 1     United States of America      97.7          54.6      98.0       99.9
# 2     United States of America      97.8          82.3      91.4       99.9
# 3     United States of America      98.3          29.5      98.1       99.2
# 4     United States of America      90.9          70.3      95.4       99.9
# ...                        ...       ...           ...       ...        ...
# 2598               South Korea      18.6          24.3      10.9       26.5
# 2599                    Turkey      14.5          14.9       7.6       19.3
# 2600                     Japan      24.0          16.1      10.2       36.4
# 2601                     Japan      20.1          23.3      16.0       13.5
# 2602                    Taiwan      16.2          17.7      18.3       28.6
#
#      income total_score num_students  student_staff_ratio  \
# 0      34.5        96.1       20,152                  8.9
# 1      83.7        96.0        2,243                  6.9
# 2      87.5        95.6       11,074                  9.0
# 3      64.3        94.3       15,596                  7.8
# 4         -        94.2        7,929                  8.4
# ...     ...         ...          ...                  ...
# 2598   35.4           -       21,958                 15.3
# 2599   44.0           -       31,268                 28.7
# 2600   37.9           -        4,122                  3.7
# 2601   40.4           -       10,117                 12.1
# 2602   39.8           -        8,663                 20.6
#
#      international_students female_male_ratio  year
# 0                       25%           54 : 46  2011
# 1                       27%           33 : 67  2011
# 2                       33%           37 : 63  2011
# 3                       22%           42 : 58  2011
# 4                       27%           45 : 55  2011
# ...                     ...               ...   ...
# 2598                     3%           48 : 52  2016
# 2599                     2%           36 : 64  2016
# 2600                     3%           54 : 46  2016
# 2601                     8%           28 : 72  2016
# 2602                     4%           43 : 57  2016
#
# [2603 rows x 14 columns]

# %%
fig = px.scatter_3d(df2014, x='world_rank', y='research', z='citations',color = 'country')
fig.show()
fig.write_html("file.html")
